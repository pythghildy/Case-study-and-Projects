# %% [markdown]
# # This case study consists of 1000 marks and the solution file is expected to be submitted in the upcoming session for evaluation.

# %% [markdown]
# # Combining Datasets: Merge and Join

# %% [markdown]
# One essential feature offered by Pandas is its high-performance, in-memory join and merge operations.
# If you have ever worked with databases, you should be familiar with this type of data interaction.
# The main interface for this is the ``pd.merge`` function, and we'll see few examples of how this can work in practice.
#
# For convenience, we will start by redefining the ``display()`` functionality from the previous section:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Specification of the Merge Key

# %% [markdown]
# We've already seen the default behavior of ``pd.merge()``: it looks for one or more matching column names between the two inputs, and uses this as the key.
# However, often the column names will not match so nicely, and ``pd.merge()`` provides a variety of options for handling this.

# %% [markdown]
# ## Example: US States Data
#
# Merge and join operations come up most often when combining data from different sources.
# Here we will consider an example of some data about US states and their populations.
# The data files can be found at http://github.com/jakevdp/data-USstates/:

# %%
# Following are shell commands to download the data
! mkdir -p data
# !cd data ; curl -O  https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-population.csv ; cd ..
# !cd data ; curl -O https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-areas.csv ; cd ..
# !cd data ; curl -O https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-abbrevs.csv ; cd ..
# Out:
# The filename, directory name, or volume label syntax is incorrect.
# The filename, directory name, or volume label syntax is incorrect.
# The filename, directory name, or volume label syntax is incorrect.

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# Let's take a look at the three datasets, using the Pandas ``read_csv()`` function:

# %%
pop = pd.read_csv('state-population.csv')
areas = pd.read_csv('state-areas.csv')
abbrevs = pd.read_csv('state-abbrevs.csv')

# %% [markdown]
# Given this information, say we want to compute a relatively straightforward result: rank US states and territories by their 2010 population density.
# We clearly have the data here to find this result, but we'll have to combine the datasets to find the result.
#
# We'll start with a many-to-one merge that will give us the full state name within the population ``DataFrame``.
# We want to merge based on the ``state/region``  column of ``pop``, and the ``abbreviation`` column of ``abbrevs``.
# We'll use ``how='outer'`` to make sure no data is thrown away due to mismatched labels.

# %% [markdown]
# ## Merge the 2 dataframes, pop and abbrevs such that all rows in both tables are included. Drop any duplicate column in the merged dataframe.

# %% [markdown]
# Let's double-check whether there were any mismatches here, which we can do by looking for rows with nulls:

# %%
#pop.head(2) #2544
#abbrevs.shape #51
merged = pop.merge(abbrevs,left_on='state/region', right_on='abbreviation', how='outer')
merged.head(2)
merged.shape
# Out:
# (2544, 6)

# %%
#drop duplicate column
merged =merged.drop('abbreviation',axis=1)
merged.shape
# Out:
# (2544, 5)

# %% [markdown]
# ## Look for any rows with null values in the new dataframe

# %%
merged.isnull().sum()
# Out:
# state/region     0
# ages             0
# year             0
# population      20
# state           96
# dtype: int64

# %% [markdown]
# ## Print out the rows in the merged dataframe that has null values for population.

# %% [markdown]
# It appears that all the null population values are from Puerto Rico prior to the year 2000; this is likely due to this data not being available from the original source.
#
# More importantly, we see also that some of the new ``state`` entries are also null, which means that there was no corresponding entry in the ``abbrevs`` key!
# Let's figure out which regions lack this match:

# %%
merged.loc[merged['state'].isnull(), 'state/region'].unique()
# Out:
# array(['PR', 'USA'], dtype=object)

# %%
merged.columns[merged.isnull().any()]
#merged.loc[merged['state'].isnull()]['state/region'].unique()
# Out:
# Index(['population', 'state'], dtype='object')

# %% [markdown]
# We can quickly infer the issue: our population data includes entries for Puerto Rico (PR) and the United States as a whole (USA), while these entries do not appear in the state abbreviation key.
# We can fix these quickly by filling in appropriate entries:

# %%
merged.loc[merged['state/region'] == 'PR', 'state'] = 'Puerto Rico'
merged.loc[merged['state/region'] == 'USA', 'state'] = 'United States'
merged.isnull().any()
# Out:
# state/region    False
# ages            False
# year            False
# population       True
# state           False
# dtype: bool

# %%
areas.head(2)
# Out:
#      state  area (sq. mi)
# 0  Alabama          52423
# 1   Alaska         656425

# %% [markdown]
# No more nulls in the ``state`` column: we're all set!
#
# Now we can merge the result with the area data using a similar procedure.
# Examining our results, we will want to join on the ``state`` column in both:

# %%
final = pd.merge(merged, areas, on='state', how='left')
final.head(2)
# Out:
#   state/region     ages  year  population    state  area (sq. mi)
# 0           AL  under18  2012   1117489.0  Alabama        52423.0
# 1           AL    total  2012   4817528.0  Alabama        52423.0

# %%
final = pd.merge(merged, areas, on='state', how='outer')
final.isnull().sum()
# Out:
# state/region      1
# ages              1
# year              1
# population       21
# state            96
# area (sq. mi)    96
# dtype: int64

# %% [markdown]
# ## Repeat the process of checking for nulls in the area field for each state in the merged dataframe and deal with them appropriately.

# %%
final[final['state'].isnull()]['state/region'].unique()
# Out:
# array(['PR', 'USA'], dtype=object)

# %%
final.loc[final['state/region'] =='PR', 'state'] = 'Puerto Rico'
final.loc[final['state/region'] == 'USA', 'state'] = 'United States'
final['state'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Select the portion of the data corresponding with the year 2000, and the total population.

# %%
final[final['year'] == 2000]
# Out:
#      state/region     ages    year   population                 state  \
# 28             AL    total  2000.0    4452173.0               Alabama
# 29             AL  under18  2000.0    1122273.0               Alabama
# 68             AK    total  2000.0     627963.0                Alaska
# 69             AK  under18  2000.0     190615.0                Alaska
# 124            AZ    total  2000.0    5160586.0               Arizona
# 125            AZ  under18  2000.0    1373414.0               Arizona
# 162            AR    total  2000.0    2678588.0              Arkansas
# 163            AR  under18  2000.0     680378.0              Arkansas
# 220            CA    total  2000.0   33987977.0            California
# 221            CA  under18  2000.0    9267089.0            California
# 258            CO    total  2000.0    4326921.0              Colorado
# 259            CO  under18  2000.0    1106676.0              Colorado
# 316            CT    total  2000.0    3411777.0           Connecticut
# 317            CT  under18  2000.0     842242.0           Connecticut
# 354            DE    total  2000.0     786373.0              Delaware
# 355            DE  under18  2000.0     194914.0              Delaware
# 412            DC    total  2000.0     572046.0  District of Columbia
# 413            DC  under18  2000.0     114503.0  District of Columbia
# 452            FL    total  2000.0   16047515.0               Florida
# 453            FL  under18  2000.0    3654880.0               Florida
# 508            GA    total  2000.0    8227303.0               Georgia
# 509            GA  under18  2000.0    2176576.0               Georgia
# 546            HI    total  2000.0    1213519.0                Hawaii
# 547            HI  under18  2000.0     295352.0                Hawaii
# 604            ID    total  2000.0    1299430.0                 Idaho
# 605            ID  under18  2000.0     370430.0                 Idaho
# 642            IL    total  2000.0   12434161.0              Illinois
# 643            IL  under18  2000.0    3244944.0              Illinois
# 700            IN    total  2000.0    6091866.0               Indiana
# 701            IN  under18  2000.0    1574989.0               Indiana
# ...           ...      ...     ...          ...                   ...
# 1852           PA    total  2000.0   12284173.0          Pennsylvania
# 1853           PA  under18  2000.0    2918850.0          Pennsylvania
# 1890           RI    total  2000.0    1050268.0          Rhode Island
# 1891           RI  under18  2000.0     248065.0          Rhode Island
# 1948           SC    total  2000.0    4024223.0        South Carolina
# 1949           SC  under18  2000.0    1010641.0        South Carolina
# 1986           SD    total  2000.0     755844.0          South Dakota
# 1987           SD  under18  2000.0     202681.0          South Dakota
# 2044           TN    total  2000.0    5703719.0             Tennessee
# 2045           TN  under18  2000.0    1399685.0             Tennessee
# 2082           TX    total  2000.0   20944499.0                 Texas
# 2083           TX  under18  2000.0    5906301.0                 Texas
# 2140           UT    total  2000.0    2244502.0                  Utah
# 2141           UT  under18  2000.0     721686.0                  Utah
# 2178           VT    total  2000.0     609618.0               Vermont
# 2179           VT  under18  2000.0     147549.0               Vermont
# 2236           VA    total  2000.0    7105817.0              Virginia
# 2237           VA  under18  2000.0    1741420.0              Virginia
# 2274           WA    total  2000.0    5910512.0            Washington
# 2275           WA  under18  2000.0    1516361.0            Washington
# 2332           WV    total  2000.0    1807021.0         West Virginia
# 2333           WV  under18  2000.0     401062.0         West Virginia
# 2372           WI    total  2000.0    5373999.0             Wisconsin
# 2373           WI  under18  2000.0    1370440.0             Wisconsin
# 2426           WY    total  2000.0     494300.0               Wyoming
# 2427           WY  under18  2000.0     128774.0               Wyoming
# 2468           PR    total  2000.0    3810605.0           Puerto Rico
# 2469           PR  under18  2000.0    1089063.0           Puerto Rico
# 2515          USA    total  2000.0  282162411.0         United States
# 2516          USA  under18  2000.0   72376189.0         United States
#
#       area (sq. mi)
# 28          52423.0
# 29          52423.0
# 68         656425.0
# 69         656425.0
# 124        114006.0
# 125        114006.0
# 162         53182.0
# 163         53182.0
# 220        163707.0
# 221        163707.0
# 258        104100.0
# 259        104100.0
# 316          5544.0
# 317          5544.0
# 354          1954.0
# 355          1954.0
# 412            68.0
# 413            68.0
# 452         65758.0
# 453         65758.0
# 508         59441.0
# 509         59441.0
# 546         10932.0
# 547         10932.0
# 604         83574.0
# 605         83574.0
# 642         57918.0
# 643         57918.0
# 700         36420.0
# 701         36420.0
# ...             ...
# 1852        46058.0
# 1853        46058.0
# 1890         1545.0
# 1891         1545.0
# 1948        32007.0
# 1949        32007.0
# 1986        77121.0
# 1987        77121.0
# 2044        42146.0
# 2045        42146.0
# 2082       268601.0
# 2083       268601.0
# 2140        84904.0
# 2141        84904.0
# 2178         9615.0
# 2179         9615.0
# 2236        42769.0
# 2237        42769.0
# 2274        71303.0
# 2275        71303.0
# 2332        24231.0
# 2333        24231.0
# 2372        65503.0
# 2373        65503.0
# 2426        97818.0
# 2427        97818.0
# 2468            NaN
# 2469            NaN
# 2515            NaN
# 2516            NaN
#
# [106 rows x 6 columns]

# %% [markdown]
# ## Re-index the data on state and find population density and display by density in ascending order

# %% [markdown]
# The result is a ranking of US states plus Washington, DC, and Puerto Rico in order of their 2010 population density, in residents per square mile.
# We can see that by far the densest region in this dataset is Washington, DC (i.e., the District of Columbia); among states, the densest is New Jersey.
#
# We can also check the end of the list:

# %% [markdown]
# We see that the least dense state, by far, is Alaska, averaging slightly over one resident per square mile.
#
# This type of messy data merging is a common task when trying to answer questions using real-world data sources.
# I hope that this example has given you an idea of the ways you can combine tools we've covered in order to gain insight from your data!

# %%
final.reindex(columns=['state']).head(2)
# Out:
#      state
# 0  Alabama
# 1  Alabama

# %%
final['population density'] = final['population']/final['area (sq. mi)']
final.sort_values('population density')
# Out:
#      state/region     ages  year   population          state  area (sq. mi)  \
# 49             AK  under18  1990     177502.0         Alaska       656425.0
# 51             AK  under18  1991     182180.0         Alaska       656425.0
# 85             AK  under18  2008     183124.0         Alaska       656425.0
# 83             AK  under18  2007     184344.0         Alaska       656425.0
# 52             AK  under18  1992     184878.0         Alaska       656425.0
# 59             AK  under18  1995     184990.0         Alaska       656425.0
# 79             AK  under18  2005     185304.0         Alaska       656425.0
# 61             AK  under18  1996     185360.0         Alaska       656425.0
# 81             AK  under18  2006     185580.0         Alaska       656425.0
# 77             AK  under18  2004     186335.0         Alaska       656425.0
# 89             AK  under18  2009     186351.0         Alaska       656425.0
# 75             AK  under18  2003     186843.0         Alaska       656425.0
# 57             AK  under18  1993     187190.0         Alaska       656425.0
# 54             AK  under18  1994     187439.0         Alaska       656425.0
# 90             AK  under18  2010     187902.0         Alaska       656425.0
# 86             AK  under18  2013     188132.0         Alaska       656425.0
# 94             AK  under18  2012     188162.0         Alaska       656425.0
# 62             AK  under18  1997     188280.0         Alaska       656425.0
# 92             AK  under18  2011     188329.0         Alaska       656425.0
# 73             AK  under18  2002     188482.0         Alaska       656425.0
# 71             AK  under18  2001     188771.0         Alaska       656425.0
# 69             AK  under18  2000     190615.0         Alaska       656425.0
# 66             AK  under18  1999     191422.0         Alaska       656425.0
# 63             AK  under18  1998     192636.0         Alaska       656425.0
# 48             AK    total  1990     553290.0         Alaska       656425.0
# 55             AK    total  1991     570193.0         Alaska       656425.0
# 50             AK    total  1992     588736.0         Alaska       656425.0
# 56             AK    total  1993     599434.0         Alaska       656425.0
# 53             AK    total  1994     603308.0         Alaska       656425.0
# 58             AK    total  1995     604412.0         Alaska       656425.0
# ...           ...      ...   ...          ...            ...            ...
# 2514          USA  under18  1999   71946051.0  United States            NaN
# 2515          USA    total  2000  282162411.0  United States            NaN
# 2516          USA  under18  2000   72376189.0  United States            NaN
# 2517          USA    total  1999  279040181.0  United States            NaN
# 2518          USA    total  2001  284968955.0  United States            NaN
# 2519          USA  under18  2001   72671175.0  United States            NaN
# 2520          USA    total  2002  287625193.0  United States            NaN
# 2521          USA  under18  2002   72936457.0  United States            NaN
# 2522          USA    total  2003  290107933.0  United States            NaN
# 2523          USA  under18  2003   73100758.0  United States            NaN
# 2524          USA    total  2004  292805298.0  United States            NaN
# 2525          USA  under18  2004   73297735.0  United States            NaN
# 2526          USA    total  2005  295516599.0  United States            NaN
# 2527          USA  under18  2005   73523669.0  United States            NaN
# 2528          USA    total  2006  298379912.0  United States            NaN
# 2529          USA  under18  2006   73757714.0  United States            NaN
# 2530          USA    total  2007  301231207.0  United States            NaN
# 2531          USA  under18  2007   74019405.0  United States            NaN
# 2532          USA    total  2008  304093966.0  United States            NaN
# 2533          USA  under18  2008   74104602.0  United States            NaN
# 2534          USA  under18  2013   73585872.0  United States            NaN
# 2535          USA    total  2013  316128839.0  United States            NaN
# 2536          USA    total  2009  306771529.0  United States            NaN
# 2537          USA  under18  2009   74134167.0  United States            NaN
# 2538          USA  under18  2010   74119556.0  United States            NaN
# 2539          USA    total  2010  309326295.0  United States            NaN
# 2540          USA  under18  2011   73902222.0  United States            NaN
# 2541          USA    total  2011  311582564.0  United States            NaN
# 2542          USA  under18  2012   73708179.0  United States            NaN
# 2543          USA    total  2012  313873685.0  United States            NaN
#
#       population density
# 49              0.270407
# 51              0.277534
# 85              0.278972
# 83              0.280830
# 52              0.281644
# 59              0.281814
# 79              0.282293
# 61              0.282378
# 81              0.282713
# 77              0.283863
# 89              0.283888
# 75              0.284637
# 57              0.285166
# 54              0.285545
# 90              0.286251
# 86              0.286601
# 94              0.286647
# 62              0.286826
# 92              0.286901
# 73              0.287134
# 71              0.287574
# 69              0.290384
# 66              0.291613
# 63              0.293462
# 48              0.842884
# 55              0.868634
# 50              0.896882
# 56              0.913180
# 53              0.919081
# 58              0.920763
# ...                  ...
# 2514                 NaN
# 2515                 NaN
# 2516                 NaN
# 2517                 NaN
# 2518                 NaN
# 2519                 NaN
# 2520                 NaN
# 2521                 NaN
# 2522                 NaN
# 2523                 NaN
# 2524                 NaN
# 2525                 NaN
# 2526                 NaN
# 2527                 NaN
# 2528                 NaN
# 2529                 NaN
# 2530                 NaN
# 2531                 NaN
# 2532                 NaN
# 2533                 NaN
# 2534                 NaN
# 2535                 NaN
# 2536                 NaN
# 2537                 NaN
# 2538                 NaN
# 2539                 NaN
# 2540                 NaN
# 2541                 NaN
# 2542                 NaN
# 2543                 NaN
#
# [2544 rows x 7 columns]
